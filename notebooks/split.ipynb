# %%
import polars as pl

df = pl.read_csv("SAML-D.csv")

# tách
df_8m = df.slice(0, 8_000_000)
df_rest = df.slice(8_000_000)

# lưu file
df_8m.write_csv("stream_data.csv")
df_rest.write_csv("dl_data.csv")
